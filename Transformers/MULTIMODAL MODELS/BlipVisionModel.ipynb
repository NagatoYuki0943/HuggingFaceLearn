# %%
import torch
from transformers import BlipProcessor, BlipVisionModel
from PIL import Image
import requests

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
version = "Salesforce/blip-image-captioning-base"
url1 = "http://images.cocodataset.org/val2017/000000039769.jpg"
url2 = "http://images.cocodataset.org/train2017/000000000081.jpg"

# %%
image1 = Image.open(requests.get(url1, stream=True).raw).convert("RGB")
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
image2 = Image.open(requests.get(url2, stream=True).raw).convert("RGB")
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x425>

# %% [markdown]
# # BlipProcessor

# %%
processor: BlipProcessor = BlipProcessor.from_pretrained(version)
processor
# Out:
# BlipProcessor:
# - image_processor: BlipImageProcessor {
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "BlipImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "processor_class": "BlipProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "height": 384,
#     "width": 384
#   }
# }
#
# - tokenizer: BertTokenizerFast(name_or_path='Salesforce/blip-image-captioning-base', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True)

# %% [markdown]
# ## processor

# %%
inputs = processor(
    images=[image1, image2],  # 可以为列表或单个string
    return_tensors="pt",  # 返回数据格式 np pt tf jax
).to(device, torch.float16)
inputs
# Out:
# {'pixel_values': tensor([[[[ 0.2661,  0.3099,  0.3391,  ..., -0.2302, -0.3178, -0.2740],
#           [ 0.2515,  0.2953,  0.4559,  ..., -0.3324, -0.2594, -0.2886],
#           [ 0.2953,  0.3683,  0.3829,  ..., -0.2740, -0.3032, -0.3470],
#           ...,
#           [ 1.6092,  1.6238,  1.5508,  ...,  1.0398,  0.9668,  0.9084],
#           [ 1.5508,  1.5800,  1.4486,  ...,  0.4121,  0.1639, -0.0550],
#           [ 1.7114,  1.5946,  1.3610,  ..., -0.4784, -0.6390, -0.7120]],
#
#          [[-1.3769, -1.4069, -1.4519,  ..., -1.6020, -1.5420, -1.5720],
#           [-1.3769, -1.3919, -1.3169,  ..., -1.5270, -1.5720, -1.5270],
#           [-1.3169, -1.3169, -1.3469,  ..., -1.4970, -1.5120, -1.5270],
#           ...,
#           [-0.3414, -0.3264, -0.3864,  ..., -0.8066, -0.8816, -0.8816],
#           [-0.4614, -0.3864, -0.4914,  ..., -1.1968, -1.3019, -1.4669],
#           [-0.2513, -0.3714, -0.6115,  ..., -1.4820, -1.5270, -1.4970]],
#
#          [[-0.6270, -0.5275, -0.4990,  ..., -0.9256, -0.9256, -0.9825],
#           [-0.7550, -0.7123, -0.4422,  ..., -0.9114, -0.9541, -0.9967],
#           [-0.7408, -0.6128, -0.6839,  ..., -0.9114, -0.9683, -1.0536],
#           ...,
#           [ 1.3069,  1.3069,  1.1932,  ...,  0.8377,  0.7666,  0.7523],
#           [ 1.4918,  1.3922,  1.2927,  ..., -0.0298, -0.2573, -0.4422],
#           [ 1.2216,  1.4065,  1.3638,  ..., -0.9256, -1.0110, -0.9256]]],
#
#
#         [[[ 0.9376,  0.9376,  0.9230,  ...,  0.7479,  0.7625,  0.7771],
#           [ 0.9376,  0.9376,  0.9376,  ...,  0.7625,  0.7479,  0.7041],
#           [ 0.9668,  0.9230,  0.9230,  ...,  0.7479,  0.7771,  0.7479],
#           ...,
#           [ 1.2442,  1.2880,  1.2880,  ...,  1.1274,  1.1128,  1.0982],
#           [ 1.2734,  1.3172,  1.3610,  ...,  1.1274,  1.1128,  1.0836],
#           [ 1.3464,  1.3318,  1.3464,  ...,  1.0690,  1.1420,  1.0982]],
#
#          [[ 1.1594,  1.1594,  1.1444,  ...,  0.9943,  1.0093,  1.0243],
#           [ 1.1744,  1.1594,  1.1594,  ...,  1.0093,  0.9943,  0.9493],
#           [ 1.1894,  1.1744,  1.1744,  ...,  1.0093,  1.0243,  0.9943],
#           ...,
#           [ 1.4446,  1.4746,  1.4596,  ...,  1.3095,  1.2945,  1.2795],
#           [ 1.4746,  1.5046,  1.5196,  ...,  1.3095,  1.2945,  1.2645],
#           [ 1.4596,  1.4896,  1.5046,  ...,  1.2945,  1.3095,  1.2645]],
#
#          [[ 1.3638,  1.3638,  1.3496,  ...,  1.1932,  1.2074,  1.2500],
#           [ 1.3354,  1.3638,  1.3638,  ...,  1.2358,  1.2358,  1.2074],
#           [ 1.3496,  1.3354,  1.3638,  ...,  1.2643,  1.2785,  1.2643],
#           ...,
#           [ 1.5913,  1.6340,  1.6198,  ...,  1.4207,  1.4207,  1.3780],
#           [ 1.6198,  1.6482,  1.6624,  ...,  1.4491,  1.4349,  1.3922],
#           [ 1.6198,  1.7051,  1.6624,  ...,  1.4349,  1.3638,  1.3922]]]],
#        device='cuda:0')}

# %%
inputs["pixel_values"].shape
# Out:
# torch.Size([2, 3, 384, 384])

# %% [markdown]
# # BlipVisionModel
#
# The model can behave as an encoder (with only self-attention) as well as a decoder

# %%
vision_model: BlipVisionModel = BlipVisionModel.from_pretrained(
    version, torch_dtype=torch.float16
).to(device)
vision_model
# Out:
# Some weights of BlipVisionModel were not initialized from the model checkpoint at Salesforce/blip-image-captioning-base and are newly initialized: ['encoder.layers.4.mlp.fc2.weight', 'encoder.layers.3.self_attn.projection.weight', 'encoder.layers.4.layer_norm1.weight', 'encoder.layers.10.self_attn.qkv.weight', 'encoder.layers.0.self_attn.projection.weight', 'encoder.layers.5.layer_norm1.bias', 'encoder.layers.6.mlp.fc2.weight', 'encoder.layers.1.layer_norm1.weight', 'encoder.layers.6.mlp.fc1.bias', 'encoder.layers.9.self_attn.projection.bias', 'encoder.layers.11.layer_norm2.bias', 'encoder.layers.5.mlp.fc1.weight', 'encoder.layers.2.layer_norm1.weight', 'encoder.layers.11.self_attn.qkv.bias', 'encoder.layers.3.layer_norm2.bias', 'encoder.layers.11.self_attn.projection.weight', 'encoder.layers.11.mlp.fc2.bias', 'encoder.layers.5.layer_norm2.weight', 'encoder.layers.0.self_attn.qkv.weight', 'encoder.layers.0.layer_norm2.bias', 'encoder.layers.8.layer_norm1.bias', 'encoder.layers.11.layer_norm2.weight', 'encoder.layers.2.layer_norm2.weight', 'encoder.layers.1.self_attn.projection.bias', 'encoder.layers.7.mlp.fc2.weight', 'encoder.layers.4.self_attn.qkv.bias', 'encoder.layers.1.layer_norm1.bias', 'encoder.layers.11.mlp.fc1.weight', 'encoder.layers.2.self_attn.projection.bias', 'encoder.layers.9.mlp.fc2.bias', 'encoder.layers.4.layer_norm1.bias', 'encoder.layers.10.self_attn.qkv.bias', 'encoder.layers.10.layer_norm2.bias', 'encoder.layers.8.mlp.fc1.bias', 'encoder.layers.4.mlp.fc1.weight', 'encoder.layers.3.self_attn.qkv.weight', 'encoder.layers.10.layer_norm1.weight', 'encoder.layers.6.mlp.fc1.weight', 'encoder.layers.3.layer_norm1.weight', 'encoder.layers.8.self_attn.qkv.bias', 'encoder.layers.3.mlp.fc2.weight', 'encoder.layers.9.layer_norm2.weight', 'encoder.layers.3.mlp.fc1.bias', 'encoder.layers.1.self_attn.qkv.bias', 'encoder.layers.11.mlp.fc1.bias', 'encoder.layers.10.mlp.fc2.weight', 'encoder.layers.8.mlp.fc1.weight', 'encoder.layers.1.mlp.fc2.bias', 'encoder.layers.2.self_attn.projection.weight', 'encoder.layers.9.mlp.fc1.weight', 'encoder.layers.10.mlp.fc1.bias', 'encoder.layers.8.layer_norm2.weight', 'encoder.layers.9.layer_norm2.bias', 'encoder.layers.6.self_attn.qkv.bias', 'encoder.layers.9.layer_norm1.weight', 'encoder.layers.10.mlp.fc2.bias', 'encoder.layers.6.self_attn.qkv.weight', 'encoder.layers.7.layer_norm1.bias', 'encoder.layers.9.self_attn.qkv.bias', 'encoder.layers.1.layer_norm2.bias', 'encoder.layers.8.mlp.fc2.weight', 'encoder.layers.11.layer_norm1.bias', 'encoder.layers.0.mlp.fc1.bias', 'encoder.layers.10.self_attn.projection.weight', 'encoder.layers.3.layer_norm2.weight', 'encoder.layers.0.layer_norm1.weight', 'embeddings.class_embedding', 'encoder.layers.0.mlp.fc2.bias', 'encoder.layers.1.mlp.fc2.weight', 'encoder.layers.11.self_attn.projection.bias', 'encoder.layers.9.layer_norm1.bias', 'encoder.layers.8.mlp.fc2.bias', 'encoder.layers.1.mlp.fc1.bias', 'encoder.layers.2.self_attn.qkv.weight', 'encoder.layers.3.self_attn.projection.bias', 'encoder.layers.2.layer_norm1.bias', 'encoder.layers.4.self_attn.projection.bias', 'encoder.layers.2.mlp.fc1.bias', 'encoder.layers.5.self_attn.projection.weight', 'encoder.layers.5.mlp.fc2.weight', 'encoder.layers.6.layer_norm1.weight', 'encoder.layers.6.self_attn.projection.weight', 'encoder.layers.11.self_attn.qkv.weight', 'encoder.layers.9.mlp.fc2.weight', 'encoder.layers.0.self_attn.qkv.bias', 'encoder.layers.5.mlp.fc1.bias', 'encoder.layers.8.self_attn.projection.bias', 'post_layernorm.weight', 'encoder.layers.5.layer_norm1.weight', 'encoder.layers.7.self_attn.qkv.bias', 'encoder.layers.5.layer_norm2.bias', 'encoder.layers.4.mlp.fc1.bias', 'encoder.layers.8.layer_norm2.bias', 'encoder.layers.8.self_attn.projection.weight', 'encoder.layers.4.self_attn.projection.weight', 'encoder.layers.5.mlp.fc2.bias', 'encoder.layers.2.mlp.fc2.weight', 'encoder.layers.0.layer_norm2.weight', 'encoder.layers.10.layer_norm1.bias', 'encoder.layers.6.layer_norm2.bias', 'encoder.layers. ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BlipVisionModel(
#   (embeddings): BlipVisionEmbeddings(
#     (patch_embedding): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#   )
#   (encoder): BlipEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x BlipEncoderLayer(
#         (self_attn): BlipAttention(
#           (dropout): Dropout(p=0.0, inplace=False)
#           (qkv): Linear(in_features=768, out_features=2304, bias=True)
#           (projection): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): BlipMLP(
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# )

# %%
vision_model.eval()
with torch.inference_mode():
    outputs = vision_model(**inputs)
outputs
# Out:
# BaseModelOutputWithPooling(last_hidden_state=tensor([[[ 0.0415, -0.8908, -0.0220,  ..., -0.7719,  0.5003,  0.6629],
#          [ 1.9777, -1.4348, -2.2036,  ..., -0.7953,  0.0067, -0.4718],
#          [ 1.5406, -1.4539, -2.0280,  ..., -0.6383, -0.2238, -0.4387],
#          ...,
#          [ 1.0360, -1.5942, -1.5953,  ..., -0.2001, -0.7693, -0.6786],
#          [ 0.9864, -0.9882, -1.5122,  ..., -0.3117, -0.0705, -0.7767],
#          [ 1.1056, -1.5685, -1.8952,  ..., -0.3931, -0.4596, -0.8966]],
#
#         [[ 0.0650, -0.7826,  0.0054,  ..., -0.1771,  0.6459,  1.8248],
#          [ 0.0424, -1.9332, -0.4941,  ...,  0.9778,  0.5749,  0.6309],
#          [ 0.0186, -1.9753, -0.4580,  ...,  0.9277,  0.5739,  0.6658],
#          ...,
#          [ 0.1592, -1.8817, -0.5897,  ...,  1.0385,  0.5364,  0.2151],
#          [ 0.1398, -1.8746, -0.5550,  ...,  1.0145,  0.5346,  0.3181],
#          [ 0.1002, -1.8469, -0.5626,  ...,  0.9849,  0.5555,  0.3701]]],
#        device='cuda:0'), pooler_output=tensor([[ 0.0415, -0.8908, -0.0220,  ..., -0.7719,  0.5003,  0.6629],
#         [ 0.0650, -0.7826,  0.0054,  ..., -0.1771,  0.6459,  1.8248]],
#        device='cuda:0'), hidden_states=None, attentions=None)

# %%
outputs.last_hidden_state.shape
# Out:
# torch.Size([2, 577, 768])

# %%
outputs.pooler_output.shape
# Out:
# torch.Size([2, 768])

# %%
outputs.hidden_states

# %%
outputs.attentions
